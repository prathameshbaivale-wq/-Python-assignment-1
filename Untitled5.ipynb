# %% [markdown]
# <a href="https://colab.research.google.com/github/prathameshbaivale-wq/-Python-assignment-1/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program for membership operators

my_list = [10, 20, 30, 40, 50]

num = int(input("Enter number to check: "))

if num in my_list:
    print(num, "is present in the list")
else:
    print(num, "is not present in the list")

if num not in my_list:
    print(num, "is not in the list")

# %%
# Program for indexing and slicing

my_list = [10, 20, 30, 40, 50]

print("List:", my_list)

# Indexing
print("First element:", my_list[0])

# Negative Indexing
print("Last element:", my_list[-1])

# Slicing
print("Elements from index 1 to 3:", my_list[1:4])
