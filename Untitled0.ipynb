# %% [markdown]
# <a href="https://colab.research.google.com/github/prathameshbaivale-wq/-Python-assignment-1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Demonstration of Python Data Types

# Integer
num = 10
print("Integer:", num)

# Float
decimal = 10.5
print("Float:", decimal)

# String
text = "Hello Python"
print("String:", text)

# Boolean
is_python_easy = True
print("Boolean:", is_python_easy)

# List
my_list = [1, 2, 3, "Apple"]
print("List:", my_list)

# Tuple
my_tuple = (10, 20, 30)
print("Tuple:", my_tuple)

# Dictionary
my_dict = {
    "Name": "Prathamesh",
    "Age": 18
}
print("Dictionary:", my_dict)

# Set
my_set = {1, 2, 3, 4}
print("Set:", my_set)
# Out:
# Integer: 10
# Float: 10.5
# String: Hello Python
# Boolean: True
# List: [1, 2, 3, 'Apple']
# Tuple: (10, 20, 30)
# Dictionary: {'Name': 'Prathamesh', 'Age': 18}
# Set: {1, 2, 3, 4}
