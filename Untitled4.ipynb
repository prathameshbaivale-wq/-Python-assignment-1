# %% [markdown]
# <a href="https://colab.research.google.com/github/prathameshbaivale-wq/-Python-assignment-1/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to calculate length of string

text = input("Enter a string: ")

print("Length of string is:", len(text))
# Out:
# Enter a string: Prathamesh
# Length of string is: 10

# %%
# Program to get first 2 and last 2 characters

text = input("Enter a string: ")

if len(text) < 2:
    print("String is too short")
else:
    result = text[:2] + text[-2:]
    print("New String:", result)
# Out:
# Enter a string: Prathamesh
# New String: Prsh

# %%
# Program to concatenate two strings

str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

result = str1 + str2

print("Concatenated String:", result)
# Out:
# Enter first string: Prathamesh
# Enter second string: Abhinav
# Concatenated String: PrathameshAbhinav
